# %%
import torch 
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader,random_split
import torch.nn as nn 
import torch.nn.functional as fn 
from torch.utils.data import DataLoader
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
##Checking if GPU is available 
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f"Selected device :{device}")
# Out:
# Selected device :cpu

# %%
##louding data 

train_set = torchvision.datasets.MNIST(root ='./.data/',train=True, download=True,transform=transforms.ToTensor())
test_set = torchvision.datasets.MNIST(root='./.data/',train=False,download=True,transform=transforms.ToTensor())

# %%
m = len(train_set)
print(m)
# Out:
# 60000

# %%
##splititng the dataset 
train_set ,val_set = random_split(train_set, [int(m-m*0.2), int(m*0.2)])

# %%
##Datalouders
train_louder = DataLoader(train_set,batch_size= 256)
test_louder = DataLoader(test_set,batch_size=256)

# %%
##Encoder Class
class Encoder(nn.Module):
    
    def __init__(self, encoded_space_dim,fc2_input_dim):
        super().__init__()
    
        self.encoder_cnn = nn.Sequential(
            nn.Conv2d(1, 8, 3, stride=2, padding=1),
            nn.ReLU(True),
            nn.Conv2d(8, 16, 3, stride=2, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            nn.Conv2d(16, 32, 3, stride=2, padding=0),
            nn.ReLU(True)
        )
        
        ### Flatten layer
        self.flatten = nn.Flatten(start_dim=1)
        self.encoder_lin = nn.Sequential(
            nn.Linear(3 * 3 * 32, 128),
            nn.ReLU(True),
            nn.Linear(128, encoded_space_dim)
        )
        
    def forward(self, x):
        x = self.encoder_cnn(x)
        x = self.flatten(x)
        x = self.encoder_lin(x)
        return x

# %%
##Decoder Class
class Decoder(nn.Module):
    
    def __init__(self, encoded_space_dim,fc2_input_dim):
        super().__init__()
        self.decoder_lin = nn.Sequential(
            nn.Linear(encoded_space_dim, 128),
            nn.ReLU(True),
            nn.Linear(128, 3 * 3 * 32),
            nn.ReLU(True)
        )

        self.unflatten = nn.Unflatten(dim=1, 
        unflattened_size=(32, 3, 3))

        self.decoder_conv = nn.Sequential(
            nn.ConvTranspose2d(32, 16, 3, 
            stride=2, output_padding=0),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            nn.ConvTranspose2d(16, 8, 3, stride=2, 
            padding=1, output_padding=1),
            nn.BatchNorm2d(8),
            nn.ReLU(True),
            nn.ConvTranspose2d(8, 1, 3, stride=2, 
            padding=1, output_padding=1)
        )
        
    def forward(self, x):
        x = self.decoder_lin(x)
        x = self.unflatten(x)
        x = self.decoder_conv(x)
        x = torch.sigmoid(x)
        return x

# %%
##
criterian = torch.nn.MSELoss()
encoder = Encoder(encoded_space_dim=4, fc2_input_dim=128)
decoder = Decoder(encoded_space_dim=4,fc2_input_dim=128)

params_to_optimize = [
    {'params': encoder.parameters()},
    {'params': decoder.parameters()}
]

optimizer = torch.optim.Adam(params_to_optimize,lr=0.001,weight_decay=1e-05)

encoder.to(device)
decoder.to(device)
# Out:
# Decoder(
#   (decoder_lin): Sequential(
#     (0): Linear(in_features=4, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=128, out_features=288, bias=True)
#     (3): ReLU(inplace=True)
#   )
#   (unflatten): Unflatten(dim=1, unflattened_size=(32, 3, 3))
#   (decoder_conv): Sequential(
#     (0): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(16, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (4): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(8, 1, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   )
# )

# %%
im = test_set[0][0].unsqueeze(0)
a = im + torch.randn_like(im)*0.3
b = torch.clip(a,0.,1.)
 
##Noise function 

def add_noise(inputs,noise_factor=0.3):
     noisy = inputs+torch.randn_like(inputs) * noise_factor
     noisy = torch.clip(noisy,0.,1.)
     return noisy

# %%
##Train function 
def training (encoder,decoder,device,datalouder,loss_fn ,optimizer,noise_factor=0.3):
    ##train mode
    encoder.train()
    decoder.train()
    train_loss = []

    ##iteration of data louder, in here we don't need the labels coz we are dealing unsupervised learning 
    for image_batch,_ in datalouder:
        image_noisy = add_noise(image_batch,noise_factor)
       ## image_batch= image_batch.to(device)
        image_noisy = image_noisy.to(device)

        ##Encoded &Decoded data 
        encoded_data = encoder(image_noisy)
        decoded_data = decoder(encoded_data)

        loss = loss_fn(decoded_data,image_noisy)
        ##backward pas
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        print('\t partial train loss (single batch): %f' % (loss.data))
        train_loss.append(loss.detach().cpu().numpy())
    return np.mean(train_loss)

# %%
### Testing function
def test_epoch_den(encoder, decoder, device, dataloader, loss_fn,noise_factor=0.3):
    encoder.eval()
    decoder.eval()
    with torch.no_grad(): 
        conc_out = []
        conc_label = []
        for image_batch, _ in dataloader:
            image_noisy = add_noise(image_batch,noise_factor)
            image_noisy = image_noisy.to(device)
            encoded_data = encoder(image_noisy)
            decoded_data = decoder(encoded_data)
            conc_out.append(decoded_data.cpu())
            conc_label.append(image_batch.cpu())
        conc_out = torch.cat(conc_out)
        conc_label = torch.cat(conc_label) 
        val_loss = loss_fn(conc_out, conc_label)
    return val_loss.data

# %%
### Training cycle
noise_factor = 0.3
num_epochs = 20
history_da={'train_loss':[],'val_loss':[]}
for epoch in range(num_epochs):
    print('EPOCH %d/%d' % (epoch + 1, num_epochs))
    train_loss=training(
        encoder=encoder, 
        decoder=decoder, 
        device=device, 
        datalouder=train_louder, 
        loss_fn=criterian, 
        optimizer=optimizer,noise_factor=noise_factor)
    val_loss = test_epoch_den(
        encoder=encoder, 
        decoder=decoder, 
        device=device, 
        dataloader=test_louder, 
        loss_fn=criterian,noise_factor=noise_factor)
    history_da['train_loss'].append(train_loss)
    history_da['val_loss'].append(val_loss)
    print('\n EPOCH {}/{} \t train loss {:.3f} \t val loss {:.3f}'.format(epoch + 1, num_epochs,train_loss,val_loss))
# Out:
# EPOCH 1/20
# 	 partial train loss (single batch): 0.065181
# 	 partial train loss (single batch): 0.064257
# 	 partial train loss (single batch): 0.065377
# 	 partial train loss (single batch): 0.064776
# 	 partial train loss (single batch): 0.064117
# 	 partial train loss (single batch): 0.065475
# 	 partial train loss (single batch): 0.064667
# 	 partial train loss (single batch): 0.063450
# 	 partial train loss (single batch): 0.064459
# 	 partial train loss (single batch): 0.064201
# 	 partial train loss (single batch): 0.063959
# 	 partial train loss (single batch): 0.063309
# 	 partial train loss (single batch): 0.064172
# 	 partial train loss (single batch): 0.064160
# 	 partial train loss (single batch): 0.064325
# 	 partial train loss (single batch): 0.064318
# 	 partial train loss (single batch): 0.063097
# 	 partial train loss (single batch): 0.064361
# 	 partial train loss (single batch): 0.063554
# 	 partial train loss (single batch): 0.063812
# 	 partial train loss (single batch): 0.062965
# 	 partial train loss (single batch): 0.063901
# 	 partial train loss (single batch): 0.064679
# 	 partial train loss (single batch): 0.064510
# 	 partial train loss (single batch): 0.064371
# 	 partial train loss (single batch): 0.064228
# 	 partial train loss (single batch): 0.063013
# 	 partial train loss (single batch): 0.062967
# 	 partial train loss (single batch): 0.063774
# 	 partial train loss (single batch): 0.063646
# 	 partial train loss (single batch): 0.063750
# 	 partial train loss (single batch): 0.063556
# 	 partial train loss (single batch): 0.062641
# 	 partial train loss (single batch): 0.063006
# 	 partial train loss (single batch): 0.064451
# 	 partial train loss (single batch): 0.064293
# 	 partial train loss (single batch): 0.062905
# 	 partial train loss (single batch): 0.063236
# 	 partial train loss (single batch): 0.062072
# 	 partial train loss (single batch): 0.063557
# 	 partial train loss (single batch): 0.063735
# 	 partial train loss (single batch): 0.063709
# 	 partial train loss (single batch): 0.062754
# 	 partial train loss (single batch): 0.062831
# 	 partial train loss (single batch): 0.063327
# 	 partial train loss (single batch): 0.062983
# 	 partial train loss (single batch): 0.063764
# 	 partial train loss (single batch): 0.062873
# 	 partial train loss (single batch): 0.063762
# 	 partial train loss (single batch): 0.063747
# 	 partial train loss (single batch): 0.062776
# 	 partial train loss (single batch): 0.063542
# 	 partial train loss (single batch): 0.061945
# 	 partial train loss (single batch): 0.064121
# 	 partial train loss (single batch): 0.062541
# 	 partial train loss (single batch): 0.062581
# 	 partial train loss (single batch): 0.062940
# 	 partial train loss (single batch): 0.063331
# 	 partial train loss (single batch): 0.062688
# 	 partial train loss (single batch): 0.063011
# 	 partial train loss (single batch): 0.062312
# 	 partial train loss (single batch): 0.063162
# 	 partial train loss (single batch): 0.063106
# 	 partial train loss (single batch): 0.062788
# 	 partial train loss (single batch): 0.062169
# 	 partial train loss (single batch): 0.062781
# 	 partial train loss (single batch): 0.062524
# 	 partial train loss (single batch): 0.062034
# 	 partial train loss (single batch): 0.062622
# 	 partial train loss (single batch): 0.062996
# 	 partial train loss (single batch): 0.062547
# 	 partial train loss (single batch): 0.062386
# 	 partial train loss (single batch): 0.062922
# 	 partial train loss (single batch): 0.061385
# 	 partial train loss (single batch): 0.062495
# 	 partial train loss (single batch): 0.063169
# 	 partial train loss (single batch): 0.062406
# 	 partial train loss (single batch): 0.062979
# 	 partial train loss (single batch): 0.061576
# 	 partial train loss (single batch): 0.063057
# 	 partial train loss (single batch): 0.062541
# 	 partial train loss (single batch): 0.061598
# 	 partial train loss (single batch): 0.063456
# 	 partial train loss (single batch): 0.062505
# 	 partial train loss (single batch): 0.062216
# 	 partial train loss (single batch): 0.062799
# 	 partial train loss (single batch): 0.061916
# 	 partial train loss (single batch): 0.062259
# 	 partial train loss (single batch): 0.062234
# 	 partial train loss (single batch): 0.061288
# 	 partial train loss (single batch): 0.062134
# 	 partial train loss (single batch): 0.063379
# 	 partial train loss (single batch): 0.062326
# 	 partial train loss (single batch): 0.062739
# 	 partial train loss (single batch): 0.060987
# 	 partial train loss (single batch): 0.062734
# 	 partial train loss (single batch): 0.062705
# 	 partial train loss (single batch): 0.062052
# 	 partial train loss (single batch): 0.062286
# 	 partial train loss (single batch): 0.060800
# 	 partial train loss (single batch): 0.062090
# 	 partial train loss (single batch): 0.061090
# 	 partial train loss (single batch): 0.061574
# 	 partial train loss (single batch): 0.061266
# 	 partial train loss (single batch): 0.062519
# 	 partial train loss (single batch): 0.061533
# 	 partial train loss (single batch): 0.061649
# 	 partial train loss (single batch): 0.061373
# 	 partial train loss (single batch): 0.061944
# 	 partial train loss (single batch): 0.061176
# 	 partial train loss (single batch): 0.060933
# 	 partial train loss (single batch): 0.061505
# 	 partial train loss (single batch): 0.061921
# 	 partial train loss (single batch): 0.062884
# 	 partial train loss (single batch): 0.062019
# 	 partial train loss (single batch): 0.061309
# 	 partial train loss (single batch): 0.060709
# 	 partial train loss (single batch): 0.060734
# 	 partial train loss (single batch): 0.061927
# 	 partial train loss (single batch): 0.062307
# 	 partial train loss (single batch): 0.061520
# 	 partial train loss (single batch): 0.061373
# 	 partial train loss (single batch): 0.062950
# 	 partial train loss (single batch): 0.061118
# 	 partial train loss (single batch): 0.059867
# 	 partial train loss (single batch): 0.060703
# 	 partial train loss (single batch): 0.060905
# 	 partial train loss (single batch): 0.060690
# 	 partial train loss (single batch): 0.061634
# 	 partial train loss (single batch): 0.061381
# 	 partial train loss (single batch): 0.062204
# 	 partial train loss (single batch): 0.061541
# 	 partial train loss (single batch): 0.061390
# 	 partial train loss (single batch): 0.060462
# 	 partial train loss (single batch): 0.061614
# 	 partial train loss (single batch): 0.062209
# 	 partial train loss (single batch): 0.061481
# 	 partial train loss (single batch): 0.062080
# 	 partial train loss (single batch): 0.061518
# 	 partial train loss (single batch): 0.061569
# 	 partial train loss (single batch): 0.060760
# 	 partial train loss (single batch): 0.061034
# 	 partial train loss (single batch): 0.061489
# 	 partial train loss (single batch): 0.061421
# 	 partial train loss (single batch): 0.061177
# 	 partial train loss (single batch): 0.060884
# 	 partial train loss (single batch): 0.060514
# 	 partial train loss (single batch): 0.061411
# 	 partial train loss (single batch): 0.060742
# 	 partial train loss (single batch): 0.061954
# 	 partial train loss (single batch): 0.061030
# 	 partial train loss (single batch): 0.062232
# 	 partial train loss (single batch): 0.061072
# 	 partial train loss (single batch): 0.061803
# 	 partial train loss (single batch): 0.060933
# 	 partial train loss (single batch): 0.061229
# 	 partial train loss (single batch): 0.060110
# 	 partial train loss (single batch): 0.060206
# 	 partial train loss (single batch): 0.062182
# 	 partial train loss (single batch): 0.060841
# 	 partial train loss (single batch): 0.060776
# 	 partial train loss (single batch): 0.060558
# 	 partial train loss (single batch): 0.060110
# 	 partial train loss (single batch): 0.060236
# 	 partial train loss (single batch): 0.061831
# 	 partial train loss (single batch): 0.061012
# 	 partial train loss (single batch): 0.061228
# 	 partial train loss (single batch): 0.061081
# 	 partial train loss (single batch): 0.060514
# 	 partial train loss (single batch): 0.061297
# 	 partial train loss (single batch): 0.061328
# 	 partial train loss (single batch): 0.060286
# 	 partial train loss (single batch): 0.060024
# 	 partial train loss (single batch): 0.061807
# 	 partial train loss (single batch): 0.060228
# 	 partial train loss (single batch): 0.060609
# 	 partial train loss (single batch): 0.061144
# 	 partial train loss (single batch): 0.061975
# 	 partial train loss (single batch): 0.060427
# 	 partial train loss (single batch): 0.060199
# 	 partial train loss (single batch): 0.060256
# 	 partial train loss (single batch): 0.059662
# 	 partial train loss (single batch): 0.059973
# 	 partial train loss (single batch): 0.061014
# 	 partial train loss (single batch): 0.059952
# 	 partial train loss (single batch): 0.060205
# 	 partial train loss (single batch): 0.059477
# 	 partial train loss (single batch): 0.060070
#
#  EPOCH 1/20 	 train loss 0.062 	 val loss 0.057
# EPOCH 2/20
# 	 partial train loss (single batch): 0.060834
# 	 partial train loss (single batch): 0.060091
# 	 partial train loss (single batch): 0.061011
# 	 partial train loss (single batch): 0.061129
# 	 partial train loss (single batch): 0.060048
# 	 partial train loss (single batch): 0.060880
# 	 partial train loss (single batch): 0.060806
# 	 partial train loss (single batch): 0.059865
# 	 partial train loss (single batch): 0.060314
# 	 partial train loss (single batch): 0.060345
# 	 partial train loss (single batch): 0.060049
# 	 partial train loss (single batch): 0.059693
# 	 partial train loss (single batch): 0.060139
# 	 partial train loss (single batch): 0.060437
# 	 partial train loss (single batch): 0.060467
# 	 partial train loss (single batch): 0.060490
# 	 partial train loss (single batch): 0.059155
# 	 partial train loss (single batch): 0.060438
# 	 partial train loss (single batch): 0.059760
# 	 partial train loss (single batch): 0.059946
# 	 partial train loss (single batch): 0.059510
# 	 partial train loss (single batch): 0.059947
# 	 partial train loss (single batch): 0.061336
# 	 partial train loss (single batch): 0.061169
# 	 partial train loss (single batch): 0.060824
# 	 partial train loss (single batch): 0.060979
# 	 partial train loss (single batch): 0.059262
# 	 partial train loss (single batch): 0.059310
# 	 partial train loss (single batch): 0.060602
# 	 partial train loss (single batch): 0.060494
# 	 partial train loss (single batch): 0.060198
# 	 partial train loss (single batch): 0.059898
# 	 partial train loss (single batch): 0.059191
# 	 partial train loss (single batch): 0.059668
# 	 partial train loss (single batch): 0.060739
# 	 partial train loss (single batch): 0.061254
# 	 partial train loss (single batch): 0.059464
# 	 partial train loss (single batch): 0.059591
# 	 partial train loss (single batch): 0.058584
# 	 partial train loss (single batch): 0.060417
# 	 partial train loss (single batch): 0.060457
# 	 partial train loss (single batch): 0.060388
# 	 partial train loss (single batch): 0.059518
# 	 partial train loss (single batch): 0.059512
# 	 partial train loss (single batch): 0.059759
# 	 partial train loss (single batch): 0.059711
# 	 partial train loss (single batch): 0.060676
# 	 partial train loss (single batch): 0.059660
# 	 partial train loss (single batch): 0.060659
# 	 partial train loss (single batch): 0.060620
# 	 partial train loss (single batch): 0.059553
# 	 partial train loss (single batch): 0.060058
# 	 partial train loss (single batch): 0.058961
# 	 partial train loss (single batch): 0.061236
# 	 partial train loss (single batch): 0.059115
# 	 partial train loss (single batch): 0.059615
# 	 partial train loss (single batch): 0.059482
# 	 partial train loss (single batch): 0.060101
# 	 partial train loss (single batch): 0.059304
# 	 partial train loss (single batch): 0.059992
# 	 partial train loss (single batch): 0.059176
# 	 partial train loss (single batch): 0.060376
# 	 partial train loss (single batch): 0.060168
# 	 partial train loss (single batch): 0.060188
# 	 partial train loss (single batch): 0.059298
# 	 partial train loss (single batch): 0.059609
# 	 partial train loss (single batch): 0.059523
# 	 partial train loss (single batch): 0.059206
# 	 partial train loss (single batch): 0.059725
# 	 partial train loss (single batch): 0.060026
# 	 partial train loss (single batch): 0.059476
# 	 partial train loss (single batch): 0.059263
# 	 partial train loss (single batch): 0.059902
# 	 partial train loss (single batch): 0.058628
# 	 partial train loss (single batch): 0.059572
# 	 partial train loss (single batch): 0.060331
# 	 partial train loss (single batch): 0.059260
# 	 partial train loss (single batch): 0.059969
# 	 partial train loss (single batch): 0.058876
# 	 partial train loss (single batch): 0.060619
# 	 partial train loss (single batch): 0.059594
# 	 partial train loss (single batch): 0.058883
# 	 partial train loss (single batch): 0.060546
# 	 partial train loss (single batch): 0.059745
# 	 partial train loss (single batch): 0.059441
# 	 partial train loss (single batch): 0.059517
# 	 partial train loss (single batch): 0.059475
# 	 partial train loss (single batch): 0.059480
# 	 partial train loss (single batch): 0.059414
# 	 partial train loss (single batch): 0.058533
# 	 partial train loss (single batch): 0.059696
# 	 partial train loss (single batch): 0.060795
# 	 partial train loss (single batch): 0.059383
# 	 partial train loss (single batch): 0.059869
# 	 partial train loss (single batch): 0.058341
# 	 partial train loss (single batch): 0.059901
# 	 partial train loss (single batch): 0.060123
# 	 partial train loss (single batch): 0.059500
# 	 partial train loss (single batch): 0.059768
# 	 partial train loss (single batch): 0.058384
# 	 partial train loss (single batch): 0.059310
# 	 partial train loss (single batch): 0.058420
# 	 partial train loss (single batch): 0.058942
# 	 partial train loss (single batch): 0.058625
# 	 partial train loss (single batch): 0.059626
# 	 partial train loss (single batch): 0.058635
# 	 partial train loss (single batch): 0.058754
# 	 partial train loss (single batch): 0.058583
# 	 partial train loss (single batch): 0.058952
# 	 partial train loss (single batch): 0.059067
# 	 partial train loss (single batch): 0.058277
# 	 partial train loss (single batch): 0.058550
# 	 partial train loss (single batch): 0.059647
# 	 partial train loss (single batch): 0.059955
# 	 partial train loss (single batch): 0.059718
# 	 partial train loss (single batch): 0.059098
# 	 partial train loss (single batch): 0.058206
# 	 partial train loss (single batch): 0.057882
# 	 partial train loss (single batch): 0.059478
# 	 partial train loss (single batch): 0.059816
# 	 partial train loss (single batch): 0.058679
# 	 partial train loss (single batch): 0.058896
# 	 partial train loss (single batch): 0.060356
# 	 partial train loss (single batch): 0.058868
# 	 partial train loss (single batch): 0.057367
# 	 partial train loss (single batch): 0.058185
# 	 partial train loss (single batch): 0.057918
# 	 partial train loss (single batch): 0.058219
# 	 partial train loss (single batch): 0.059184
# 	 partial train loss (single batch): 0.058897
# 	 partial train loss (single batch): 0.059352
# 	 partial train loss (single batch): 0.059140
# 	 partial train loss (single batch): 0.058881
# 	 partial train loss (single batch): 0.058156
# 	 partial train loss (single batch): 0.058991
# 	 partial train loss (single batch): 0.059456
# 	 partial train loss (single batch): 0.059106
# 	 partial train loss (single batch): 0.059233
# 	 partial train loss (single batch): 0.058849
# 	 partial train loss (single batch): 0.059210
# 	 partial train loss (single batch): 0.058545
# 	 partial train loss (single batch): 0.058631
# 	 partial train loss (single batch): 0.058589
# 	 partial train loss (single batch): 0.059154
# 	 partial train loss (single batch): 0.058800
# 	 partial train loss (single batch): 0.058213
# 	 partial train loss (single batch): 0.058180
# 	 partial train loss (single batch): 0.058684
# 	 partial train loss (single batch): 0.057998
# 	 partial train loss (single batch): 0.059482
# 	 partial train loss (single batch): 0.058588
# 	 partial train loss (single batch): 0.059491
# 	 partial train loss (single batch): 0.058412
# 	 partial train loss (single batch): 0.058538
# 	 partial train loss (single batch): 0.058318
# 	 partial train loss (single batch): 0.058471
# 	 partial train loss (single batch): 0.057984
# 	 partial train loss (single batch): 0.057596
# 	 partial train loss (single batch): 0.059731
# 	 partial train loss (single batch): 0.057996
# 	 partial train loss (single batch): 0.058309
# 	 partial train loss (single batch): 0.058076
# 	 partial train loss (single batch): 0.058065
# 	 partial train loss (single batch): 0.057748
# 	 partial train loss (single batch): 0.059447
# 	 partial train loss (single batch): 0.058485
# 	 partial train loss (single batch): 0.058644
# 	 partial train loss (single batch): 0.058073
# 	 partial train loss (single batch): 0.057924
# 	 partial train loss (single batch): 0.058949
# 	 partial train loss (single batch): 0.058525
# 	 partial train loss (single batch): 0.057590
# 	 partial train loss (single batch): 0.057082
# 	 partial train loss (single batch): 0.058937
# 	 partial train loss (single batch): 0.057804
# 	 partial train loss (single batch): 0.058065
# 	 partial train loss (single batch): 0.058783
# 	 partial train loss (single batch): 0.059563
# 	 partial train loss (single batch): 0.058181
# 	 partial train loss (single batch): 0.057500
# 	 partial train loss (single batch): 0.058053
# 	 partial train loss (single batch): 0.057331
# 	 partial train loss (single batch): 0.057328
# 	 partial train loss (single batch): 0.058355
# 	 partial train loss (single batch): 0.057268
# 	 partial train loss (single batch): 0.057745
# 	 partial train loss (single batch): 0.056827
# 	 partial train loss (single batch): 0.058186
#
#  EPOCH 2/20 	 train loss 0.059 	 val loss 0.052
# EPOCH 3/20
# 	 partial train loss (single batch): 0.058639
# 	 partial train loss (single batch): 0.057888
# 	 partial train loss (single batch): 0.058830
# 	 partial train loss (single batch): 0.058223
# 	 partial train loss (single batch): 0.057013
# 	 partial train loss (single batch): 0.058625
# 	 partial train loss (single batch): 0.058070
# 	 partial train loss (single batch): 0.056997
# 	 partial train loss (single batch): 0.057487
# 	 partial train loss (single batch): 0.057869
# 	 partial train loss (single batch): 0.057597
# 	 partial train loss (single batch): 0.057344
# 	 partial train loss (single batch): 0.057527
# 	 partial train loss (single batch): 0.057880
# 	 partial train loss (single batch): 0.057844
# 	 partial train loss (single batch): 0.057815
# 	 partial train loss (single batch): 0.056954
# 	 partial train loss (single batch): 0.057416
# 	 partial train loss (single batch): 0.057482
# 	 partial train loss (single batch): 0.057421
# 	 partial train loss (single batch): 0.056955
# 	 partial train loss (single batch): 0.057162
# 	 partial train loss (single batch): 0.058840
# 	 partial train loss (single batch): 0.058193
# 	 partial train loss (single batch): 0.058086
# 	 partial train loss (single batch): 0.058427
# 	 partial train loss (single batch): 0.056818
# 	 partial train loss (single batch): 0.056703
# 	 partial train loss (single batch): 0.057517
# 	 partial train loss (single batch): 0.058152
# 	 partial train loss (single batch): 0.057610
# 	 partial train loss (single batch): 0.057880
# 	 partial train loss (single batch): 0.056755
# 	 partial train loss (single batch): 0.056866
# 	 partial train loss (single batch): 0.058127
# 	 partial train loss (single batch): 0.058153
# 	 partial train loss (single batch): 0.057237
# 	 partial train loss (single batch): 0.057285
# 	 partial train loss (single batch): 0.056259
# 	 partial train loss (single batch): 0.058148
# 	 partial train loss (single batch): 0.057817
# 	 partial train loss (single batch): 0.057903
# 	 partial train loss (single batch): 0.056883
# 	 partial train loss (single batch): 0.056689
# 	 partial train loss (single batch): 0.057437
# 	 partial train loss (single batch): 0.057481
# 	 partial train loss (single batch): 0.057942
# 	 partial train loss (single batch): 0.056984
# 	 partial train loss (single batch): 0.057841
# 	 partial train loss (single batch): 0.058334
# 	 partial train loss (single batch): 0.057408
# 	 partial train loss (single batch): 0.057658
# 	 partial train loss (single batch): 0.056311
# 	 partial train loss (single batch): 0.058485
# 	 partial train loss (single batch): 0.056853
# 	 partial train loss (single batch): 0.057001
# 	 partial train loss (single batch): 0.057568
# 	 partial train loss (single batch): 0.057695
# 	 partial train loss (single batch): 0.056882
# 	 partial train loss (single batch): 0.057208
# 	 partial train loss (single batch): 0.056908
# 	 partial train loss (single batch): 0.057772
# 	 partial train loss (single batch): 0.057778
# 	 partial train loss (single batch): 0.057286
# 	 partial train loss (single batch): 0.056393
# 	 partial train loss (single batch): 0.057088
# 	 partial train loss (single batch): 0.057252
# 	 partial train loss (single batch): 0.057036
# 	 partial train loss (single batch): 0.056897
# 	 partial train loss (single batch): 0.057520
# 	 partial train loss (single batch): 0.056804
# 	 partial train loss (single batch): 0.056465
# 	 partial train loss (single batch): 0.057634
# 	 partial train loss (single batch): 0.055637
# 	 partial train loss (single batch): 0.057150
# 	 partial train loss (single batch): 0.057400
# 	 partial train loss (single batch): 0.056680
# 	 partial train loss (single batch): 0.057433
# 	 partial train loss (single batch): 0.056215
# 	 partial train loss (single batch): 0.057469
# 	 partial train loss (single batch): 0.056804
# 	 partial train loss (single batch): 0.056297
# 	 partial train loss (single batch): 0.058185
# 	 partial train loss (single batch): 0.056807
# 	 partial train loss (single batch): 0.056831
# 	 partial train loss (single batch): 0.056570
# 	 partial train loss (single batch): 0.056533
# 	 partial train loss (single batch): 0.056846
# 	 partial train loss (single batch): 0.057018
# 	 partial train loss (single batch): 0.056076
# 	 partial train loss (single batch): 0.056884
# 	 partial train loss (single batch): 0.058085
# 	 partial train loss (single batch): 0.057325
# 	 partial train loss (single batch): 0.057372
# 	 partial train loss (single batch): 0.055882
# 	 partial train loss (single batch): 0.057483
# 	 partial train loss (single batch): 0.057927
# 	 partial train loss (single batch): 0.057463
# 	 partial train loss (single batch): 0.057009
# 	 partial train loss (single batch): 0.056029
# 	 partial train loss (single batch): 0.056611
# 	 partial train loss (single batch): 0.056064
# 	 partial train loss (single batch): 0.056405
# 	 partial train loss (single batch): 0.056449
# 	 partial train loss (single batch): 0.057455
# 	 partial train loss (single batch): 0.056079
# 	 partial train loss (single batch): 0.056182
# 	 partial train loss (single batch): 0.056216
# 	 partial train loss (single batch): 0.056598
# 	 partial train loss (single batch): 0.056022
# 	 partial train loss (single batch): 0.055470
# 	 partial train loss (single batch): 0.056316
# 	 partial train loss (single batch): 0.057209
# 	 partial train loss (single batch): 0.057574
# 	 partial train loss (single batch): 0.057186
# 	 partial train loss (single batch): 0.056603
# 	 partial train loss (single batch): 0.055017
# 	 partial train loss (single batch): 0.055366
# 	 partial train loss (single batch): 0.056893
# 	 partial train loss (single batch): 0.057277
# 	 partial train loss (single batch): 0.056827
# 	 partial train loss (single batch): 0.056280
# 	 partial train loss (single batch): 0.057504
# 	 partial train loss (single batch): 0.056266
# 	 partial train loss (single batch): 0.054725
# 	 partial train loss (single batch): 0.055538
# 	 partial train loss (single batch): 0.055189
# 	 partial train loss (single batch): 0.056077
# 	 partial train loss (single batch): 0.057042
# 	 partial train loss (single batch): 0.057167
# 	 partial train loss (single batch): 0.056860
# 	 partial train loss (single batch): 0.056743
# 	 partial train loss (single batch): 0.056620
# 	 partial train loss (single batch): 0.055767
# 	 partial train loss (single batch): 0.056600
# 	 partial train loss (single batch): 0.057023
# 	 partial train loss (single batch): 0.056223
# 	 partial train loss (single batch): 0.056889
# 	 partial train loss (single batch): 0.056791
# 	 partial train loss (single batch): 0.057107
# 	 partial train loss (single batch): 0.056499
# 	 partial train loss (single batch): 0.056077
# 	 partial train loss (single batch): 0.056426
# 	 partial train loss (single batch): 0.056447
# 	 partial train loss (single batch): 0.056124
# 	 partial train loss (single batch): 0.055552
# 	 partial train loss (single batch): 0.056177
# 	 partial train loss (single batch): 0.056312
# 	 partial train loss (single batch): 0.055821
# 	 partial train loss (single batch): 0.057040
# 	 partial train loss (single batch): 0.055906
# 	 partial train loss (single batch): 0.057357
# 	 partial train loss (single batch): 0.055576
# 	 partial train loss (single batch): 0.056491
# 	 partial train loss (single batch): 0.056539
# 	 partial train loss (single batch): 0.055972
# 	 partial train loss (single batch): 0.055368
# 	 partial train loss (single batch): 0.055582
# 	 partial train loss (single batch): 0.057060
# 	 partial train loss (single batch): 0.055767
# 	 partial train loss (single batch): 0.056441
# 	 partial train loss (single batch): 0.055424
# 	 partial train loss (single batch): 0.056085
# 	 partial train loss (single batch): 0.055273
# 	 partial train loss (single batch): 0.056901
# 	 partial train loss (single batch): 0.055871
# 	 partial train loss (single batch): 0.056190
# 	 partial train loss (single batch): 0.055842
# 	 partial train loss (single batch): 0.055674
# 	 partial train loss (single batch): 0.056142
# 	 partial train loss (single batch): 0.056265
# 	 partial train loss (single batch): 0.055185
# 	 partial train loss (single batch): 0.054987
# 	 partial train loss (single batch): 0.056481
# 	 partial train loss (single batch): 0.055708
# 	 partial train loss (single batch): 0.055304
# 	 partial train loss (single batch): 0.055977
# 	 partial train loss (single batch): 0.057041
# 	 partial train loss (single batch): 0.055900
# 	 partial train loss (single batch): 0.055581
# 	 partial train loss (single batch): 0.055662
# 	 partial train loss (single batch): 0.054995
# 	 partial train loss (single batch): 0.055019
# 	 partial train loss (single batch): 0.056070
# 	 partial train loss (single batch): 0.055191
# 	 partial train loss (single batch): 0.054889
# 	 partial train loss (single batch): 0.054565
# 	 partial train loss (single batch): 0.055684
#
#  EPOCH 3/20 	 train loss 0.057 	 val loss 0.048
# EPOCH 4/20
# 	 partial train loss (single batch): 0.056475
# 	 partial train loss (single batch): 0.055360
# 	 partial train loss (single batch): 0.056104
# 	 partial train loss (single batch): 0.055935
# 	 partial train loss (single batch): 0.054681
# 	 partial train loss (single batch): 0.056176
# 	 partial train loss (single batch): 0.056033
# 	 partial train loss (single batch): 0.054761
# 	 partial train loss (single batch): 0.055420
# 	 partial train loss (single batch): 0.055368
# 	 partial train loss (single batch): 0.055599
# 	 partial train loss (single batch): 0.055265
# 	 partial train loss (single batch): 0.055157
# 	 partial train loss (single batch): 0.055817
# 	 partial train loss (single batch): 0.055737
# 	 partial train loss (single batch): 0.055666
# 	 partial train loss (single batch): 0.054328
# 	 partial train loss (single batch): 0.055445
# 	 partial train loss (single batch): 0.055273
# 	 partial train loss (single batch): 0.055388
# 	 partial train loss (single batch): 0.054761
# 	 partial train loss (single batch): 0.055201
# 	 partial train loss (single batch): 0.055984
# 	 partial train loss (single batch): 0.056001
# 	 partial train loss (single batch): 0.055772
# 	 partial train loss (single batch): 0.055668
# 	 partial train loss (single batch): 0.054991
# 	 partial train loss (single batch): 0.054427
# 	 partial train loss (single batch): 0.055642
# 	 partial train loss (single batch): 0.055767
# 	 partial train loss (single batch): 0.055111
# 	 partial train loss (single batch): 0.055235
# 	 partial train loss (single batch): 0.054506
# 	 partial train loss (single batch): 0.054831
# 	 partial train loss (single batch): 0.055512
# 	 partial train loss (single batch): 0.055716
# 	 partial train loss (single batch): 0.054849
# 	 partial train loss (single batch): 0.055424
# 	 partial train loss (single batch): 0.053687
# 	 partial train loss (single batch): 0.055846
# 	 partial train loss (single batch): 0.055669
# 	 partial train loss (single batch): 0.055639
# 	 partial train loss (single batch): 0.055092
# 	 partial train loss (single batch): 0.054346
# 	 partial train loss (single batch): 0.055005
# 	 partial train loss (single batch): 0.055204
# 	 partial train loss (single batch): 0.055839
# 	 partial train loss (single batch): 0.054822
# 	 partial train loss (single batch): 0.055100
# 	 partial train loss (single batch): 0.055606
# 	 partial train loss (single batch): 0.054703
# 	 partial train loss (single batch): 0.055299
# 	 partial train loss (single batch): 0.053885
# 	 partial train loss (single batch): 0.055901
# 	 partial train loss (single batch): 0.054797
# 	 partial train loss (single batch): 0.054785
# 	 partial train loss (single batch): 0.054947
# 	 partial train loss (single batch): 0.055261
# 	 partial train loss (single batch): 0.054613
# 	 partial train loss (single batch): 0.055052
# 	 partial train loss (single batch): 0.054884
# 	 partial train loss (single batch): 0.055760
# 	 partial train loss (single batch): 0.055681
# 	 partial train loss (single batch): 0.054911
# 	 partial train loss (single batch): 0.054441
# 	 partial train loss (single batch): 0.054648
# 	 partial train loss (single batch): 0.054781
# 	 partial train loss (single batch): 0.054479
# 	 partial train loss (single batch): 0.054764
# 	 partial train loss (single batch): 0.055216
# 	 partial train loss (single batch): 0.054833
# 	 partial train loss (single batch): 0.054489
# 	 partial train loss (single batch): 0.055726
# 	 partial train loss (single batch): 0.053326
# 	 partial train loss (single batch): 0.055278
# 	 partial train loss (single batch): 0.055015
# 	 partial train loss (single batch): 0.054786
# 	 partial train loss (single batch): 0.055059
# 	 partial train loss (single batch): 0.054615
# 	 partial train loss (single batch): 0.055530
# 	 partial train loss (single batch): 0.054609
# 	 partial train loss (single batch): 0.054137
# 	 partial train loss (single batch): 0.056090
# 	 partial train loss (single batch): 0.055286
# 	 partial train loss (single batch): 0.054573
# 	 partial train loss (single batch): 0.054488
# 	 partial train loss (single batch): 0.054711
# 	 partial train loss (single batch): 0.054384
# 	 partial train loss (single batch): 0.054964
# 	 partial train loss (single batch): 0.054399
# 	 partial train loss (single batch): 0.055079
# 	 partial train loss (single batch): 0.055895
# 	 partial train loss (single batch): 0.054873
# 	 partial train loss (single batch): 0.054705
# 	 partial train loss (single batch): 0.054365
# 	 partial train loss (single batch): 0.055840
# 	 partial train loss (single batch): 0.055968
# 	 partial train loss (single batch): 0.055478
# 	 partial train loss (single batch): 0.055412
# 	 partial train loss (single batch): 0.054420
# 	 partial train loss (single batch): 0.054869
# 	 partial train loss (single batch): 0.053867
# 	 partial train loss (single batch): 0.054273
# 	 partial train loss (single batch): 0.054582
# 	 partial train loss (single batch): 0.055299
# 	 partial train loss (single batch): 0.054066
# 	 partial train loss (single batch): 0.054422
# 	 partial train loss (single batch): 0.053995
# 	 partial train loss (single batch): 0.054610
# 	 partial train loss (single batch): 0.054100
# 	 partial train loss (single batch): 0.053715
# 	 partial train loss (single batch): 0.054574
# 	 partial train loss (single batch): 0.054945
# 	 partial train loss (single batch): 0.055295
# 	 partial train loss (single batch): 0.055011
# 	 partial train loss (single batch): 0.054756
# 	 partial train loss (single batch): 0.052885
# 	 partial train loss (single batch): 0.053409
# 	 partial train loss (single batch): 0.054850
# 	 partial train loss (single batch): 0.055290
# 	 partial train loss (single batch): 0.054493
# 	 partial train loss (single batch): 0.053912
# 	 partial train loss (single batch): 0.055616
# 	 partial train loss (single batch): 0.054177
# 	 partial train loss (single batch): 0.053082
# 	 partial train loss (single batch): 0.053520
# 	 partial train loss (single batch): 0.052727
# 	 partial train loss (single batch): 0.054001
# 	 partial train loss (single batch): 0.054757
# 	 partial train loss (single batch): 0.054856
# 	 partial train loss (single batch): 0.054459
# 	 partial train loss (single batch): 0.054379
# 	 partial train loss (single batch): 0.054820
# 	 partial train loss (single batch): 0.054342
# 	 partial train loss (single batch): 0.054775
# 	 partial train loss (single batch): 0.055584
# 	 partial train loss (single batch): 0.054662
# 	 partial train loss (single batch): 0.055317
# 	 partial train loss (single batch): 0.054546
# 	 partial train loss (single batch): 0.055485
# 	 partial train loss (single batch): 0.054618
# 	 partial train loss (single batch): 0.053977
# 	 partial train loss (single batch): 0.054363
# 	 partial train loss (single batch): 0.054326
# 	 partial train loss (single batch): 0.054427
# 	 partial train loss (single batch): 0.053522
# 	 partial train loss (single batch): 0.053723
# 	 partial train loss (single batch): 0.054433
# 	 partial train loss (single batch): 0.054479
# 	 partial train loss (single batch): 0.054696
# 	 partial train loss (single batch): 0.054267
# 	 partial train loss (single batch): 0.055153
# 	 partial train loss (single batch): 0.053523
# 	 partial train loss (single batch): 0.054599
# 	 partial train loss (single batch): 0.054560
# 	 partial train loss (single batch): 0.054269
# 	 partial train loss (single batch): 0.053633
# 	 partial train loss (single batch): 0.053545
# 	 partial train loss (single batch): 0.054761
# 	 partial train loss (single batch): 0.053982
# 	 partial train loss (single batch): 0.054543
# 	 partial train loss (single batch): 0.053328
# 	 partial train loss (single batch): 0.054137
# 	 partial train loss (single batch): 0.053589
# 	 partial train loss (single batch): 0.055222
# 	 partial train loss (single batch): 0.054048
# 	 partial train loss (single batch): 0.054307
# 	 partial train loss (single batch): 0.053767
# 	 partial train loss (single batch): 0.053201
# 	 partial train loss (single batch): 0.054319
# 	 partial train loss (single batch): 0.054548
# 	 partial train loss (single batch): 0.053070
# 	 partial train loss (single batch): 0.053049
# 	 partial train loss (single batch): 0.054078
# 	 partial train loss (single batch): 0.053460
# 	 partial train loss (single batch): 0.053882
# 	 partial train loss (single batch): 0.054127
# 	 partial train loss (single batch): 0.055125
# 	 partial train loss (single batch): 0.053605
# 	 partial train loss (single batch): 0.053903
# 	 partial train loss (single batch): 0.054157
# 	 partial train loss (single batch): 0.053106
# 	 partial train loss (single batch): 0.053316
# 	 partial train loss (single batch): 0.054412
# 	 partial train loss (single batch): 0.053206
# 	 partial train loss (single batch): 0.053392
# 	 partial train loss (single batch): 0.052440
# 	 partial train loss (single batch): 0.053954
#
#  EPOCH 4/20 	 train loss 0.055 	 val loss 0.045
# EPOCH 5/20
# 	 partial train loss (single batch): 0.054742
# 	 partial train loss (single batch): 0.053416
# 	 partial train loss (single batch): 0.054329
# 	 partial train loss (single batch): 0.054295
# 	 partial train loss (single batch): 0.052775
# 	 partial train loss (single batch): 0.054503
# 	 partial train loss (single batch): 0.054047
# 	 partial train loss (single batch): 0.052918
# 	 partial train loss (single batch): 0.053667
# 	 partial train loss (single batch): 0.053636
# 	 partial train loss (single batch): 0.053706
# 	 partial train loss (single batch): 0.053683
# 	 partial train loss (single batch): 0.052762
# 	 partial train loss (single batch): 0.054336
# 	 partial train loss (single batch): 0.054091
# 	 partial train loss (single batch): 0.053877
# 	 partial train loss (single batch): 0.052612
# 	 partial train loss (single batch): 0.053876
# 	 partial train loss (single batch): 0.053674
# 	 partial train loss (single batch): 0.053664
# 	 partial train loss (single batch): 0.053023
# 	 partial train loss (single batch): 0.053130
# 	 partial train loss (single batch): 0.053829
# 	 partial train loss (single batch): 0.054316
# 	 partial train loss (single batch): 0.053850
# 	 partial train loss (single batch): 0.054353
# 	 partial train loss (single batch): 0.052959
# 	 partial train loss (single batch): 0.053123
# 	 partial train loss (single batch): 0.053773
# 	 partial train loss (single batch): 0.054084
# 	 partial train loss (single batch): 0.053804
# 	 partial train loss (single batch): 0.054226
# 	 partial train loss (single batch): 0.052778
# 	 partial train loss (single batch): 0.053241
# 	 partial train loss (single batch): 0.053901
# 	 partial train loss (single batch): 0.054645
# 	 partial train loss (single batch): 0.053296
# 	 partial train loss (single batch): 0.053859
# 	 partial train loss (single batch): 0.052140
# 	 partial train loss (single batch): 0.053838
# 	 partial train loss (single batch): 0.053868
# 	 partial train loss (single batch): 0.054469
# 	 partial train loss (single batch): 0.053129
# 	 partial train loss (single batch): 0.052730
# 	 partial train loss (single batch): 0.053857
# 	 partial train loss (single batch): 0.053688
# 	 partial train loss (single batch): 0.053830
# 	 partial train loss (single batch): 0.053310
# 	 partial train loss (single batch): 0.053882
# 	 partial train loss (single batch): 0.054495
# 	 partial train loss (single batch): 0.053636
# 	 partial train loss (single batch): 0.053708
# 	 partial train loss (single batch): 0.052772
# 	 partial train loss (single batch): 0.054286
# 	 partial train loss (single batch): 0.053197
# 	 partial train loss (single batch): 0.053366
# 	 partial train loss (single batch): 0.053476
# 	 partial train loss (single batch): 0.053705
# 	 partial train loss (single batch): 0.053066
# 	 partial train loss (single batch): 0.053254
# 	 partial train loss (single batch): 0.053044
# 	 partial train loss (single batch): 0.053749
# 	 partial train loss (single batch): 0.053905
# 	 partial train loss (single batch): 0.053218
# 	 partial train loss (single batch): 0.052724
# 	 partial train loss (single batch): 0.052975
# 	 partial train loss (single batch): 0.053126
# 	 partial train loss (single batch): 0.053160
# 	 partial train loss (single batch): 0.053170
# 	 partial train loss (single batch): 0.053867
# 	 partial train loss (single batch): 0.052899
# 	 partial train loss (single batch): 0.052373
# 	 partial train loss (single batch): 0.054324
# 	 partial train loss (single batch): 0.052151
# 	 partial train loss (single batch): 0.053466
# 	 partial train loss (single batch): 0.052802
# 	 partial train loss (single batch): 0.053034
# 	 partial train loss (single batch): 0.053789
# 	 partial train loss (single batch): 0.052760
# 	 partial train loss (single batch): 0.053973
# 	 partial train loss (single batch): 0.052684
# 	 partial train loss (single batch): 0.052726
# 	 partial train loss (single batch): 0.054019
# 	 partial train loss (single batch): 0.053487
# 	 partial train loss (single batch): 0.052897
# 	 partial train loss (single batch): 0.052533
# 	 partial train loss (single batch): 0.053193
# 	 partial train loss (single batch): 0.053015
# 	 partial train loss (single batch): 0.053079
# 	 partial train loss (single batch): 0.052861
# 	 partial train loss (single batch): 0.053082
# 	 partial train loss (single batch): 0.054179
# 	 partial train loss (single batch): 0.053436
# 	 partial train loss (single batch): 0.053139
# 	 partial train loss (single batch): 0.052858
# 	 partial train loss (single batch): 0.054450
# 	 partial train loss (single batch): 0.054532
# 	 partial train loss (single batch): 0.053705
# 	 partial train loss (single batch): 0.053321
# 	 partial train loss (single batch): 0.053075
# 	 partial train loss (single batch): 0.052908
# 	 partial train loss (single batch): 0.052320
# 	 partial train loss (single batch): 0.052944
# 	 partial train loss (single batch): 0.053247
# 	 partial train loss (single batch): 0.053243
# 	 partial train loss (single batch): 0.052306
# 	 partial train loss (single batch): 0.053004
# 	 partial train loss (single batch): 0.052279
# 	 partial train loss (single batch): 0.052980
# 	 partial train loss (single batch): 0.052397
# 	 partial train loss (single batch): 0.052229
# 	 partial train loss (single batch): 0.052918
# 	 partial train loss (single batch): 0.053273
# 	 partial train loss (single batch): 0.053607
# 	 partial train loss (single batch): 0.053571
# 	 partial train loss (single batch): 0.053131
# 	 partial train loss (single batch): 0.051287
# 	 partial train loss (single batch): 0.051758
# 	 partial train loss (single batch): 0.053300
# 	 partial train loss (single batch): 0.053794
# 	 partial train loss (single batch): 0.052948
# 	 partial train loss (single batch): 0.052540
# 	 partial train loss (single batch): 0.054449
# 	 partial train loss (single batch): 0.052744
# 	 partial train loss (single batch): 0.051479
# 	 partial train loss (single batch): 0.052394
# 	 partial train loss (single batch): 0.051105
# 	 partial train loss (single batch): 0.052645
# 	 partial train loss (single batch): 0.053093
# 	 partial train loss (single batch): 0.053481
# 	 partial train loss (single batch): 0.053023
# 	 partial train loss (single batch): 0.052784
# 	 partial train loss (single batch): 0.053049
# 	 partial train loss (single batch): 0.053098
# 	 partial train loss (single batch): 0.053204
# 	 partial train loss (single batch): 0.053891
# 	 partial train loss (single batch): 0.053002
# 	 partial train loss (single batch): 0.053878
# 	 partial train loss (single batch): 0.053175
# 	 partial train loss (single batch): 0.053819
# 	 partial train loss (single batch): 0.053721
# 	 partial train loss (single batch): 0.052457
# 	 partial train loss (single batch): 0.052615
# 	 partial train loss (single batch): 0.052698
# 	 partial train loss (single batch): 0.053065
# 	 partial train loss (single batch): 0.052377
# 	 partial train loss (single batch): 0.052376
# 	 partial train loss (single batch): 0.052693
# 	 partial train loss (single batch): 0.052817
# 	 partial train loss (single batch): 0.053420
# 	 partial train loss (single batch): 0.052574
# 	 partial train loss (single batch): 0.053378
# 	 partial train loss (single batch): 0.052226
# 	 partial train loss (single batch): 0.053368
# 	 partial train loss (single batch): 0.052975
# 	 partial train loss (single batch): 0.052923
# 	 partial train loss (single batch): 0.052370
# 	 partial train loss (single batch): 0.052280
# 	 partial train loss (single batch): 0.053353
# 	 partial train loss (single batch): 0.052362
# 	 partial train loss (single batch): 0.053172
# 	 partial train loss (single batch): 0.051742
# 	 partial train loss (single batch): 0.052954
# 	 partial train loss (single batch): 0.052377
# 	 partial train loss (single batch): 0.053701
# 	 partial train loss (single batch): 0.052593
# 	 partial train loss (single batch): 0.053342
# 	 partial train loss (single batch): 0.052500
# 	 partial train loss (single batch): 0.052076
# 	 partial train loss (single batch): 0.053297
# 	 partial train loss (single batch): 0.053051
# 	 partial train loss (single batch): 0.051557
# 	 partial train loss (single batch): 0.051428
# 	 partial train loss (single batch): 0.052885
# 	 partial train loss (single batch): 0.052721
# 	 partial train loss (single batch): 0.052253
# 	 partial train loss (single batch): 0.053024
# 	 partial train loss (single batch): 0.053911
# 	 partial train loss (single batch): 0.052771
# 	 partial train loss (single batch): 0.052488
# 	 partial train loss (single batch): 0.052535
# 	 partial train loss (single batch): 0.052048
# 	 partial train loss (single batch): 0.052125
# 	 partial train loss (single batch): 0.053253
# 	 partial train loss (single batch): 0.052273
# 	 partial train loss (single batch): 0.052184
# 	 partial train loss (single batch): 0.051711
# 	 partial train loss (single batch): 0.052385
#
#  EPOCH 5/20 	 train loss 0.053 	 val loss 0.043
# EPOCH 6/20
# 	 partial train loss (single batch): 0.053637
# 	 partial train loss (single batch): 0.052449
# 	 partial train loss (single batch): 0.053236
# 	 partial train loss (single batch): 0.053063
# 	 partial train loss (single batch): 0.051497
# 	 partial train loss (single batch): 0.053264
# 	 partial train loss (single batch): 0.052419
# 	 partial train loss (single batch): 0.051440
# 	 partial train loss (single batch): 0.052344
# 	 partial train loss (single batch): 0.052571
# 	 partial train loss (single batch): 0.052306
# 	 partial train loss (single batch): 0.052516
# 	 partial train loss (single batch): 0.051485
# 	 partial train loss (single batch): 0.053019
# 	 partial train loss (single batch): 0.052822
# 	 partial train loss (single batch): 0.053116
# 	 partial train loss (single batch): 0.051716
# 	 partial train loss (single batch): 0.052315
# 	 partial train loss (single batch): 0.052416
# 	 partial train loss (single batch): 0.051906
# 	 partial train loss (single batch): 0.052076
# 	 partial train loss (single batch): 0.052154
# 	 partial train loss (single batch): 0.052960
# 	 partial train loss (single batch): 0.052961
# 	 partial train loss (single batch): 0.052659
# 	 partial train loss (single batch): 0.052688
# 	 partial train loss (single batch): 0.052053
# 	 partial train loss (single batch): 0.051436
# 	 partial train loss (single batch): 0.052797
# 	 partial train loss (single batch): 0.053164
# 	 partial train loss (single batch): 0.052483
# 	 partial train loss (single batch): 0.052847
# 	 partial train loss (single batch): 0.051631
# 	 partial train loss (single batch): 0.051940
# 	 partial train loss (single batch): 0.052737
# 	 partial train loss (single batch): 0.053124
# 	 partial train loss (single batch): 0.052185
# 	 partial train loss (single batch): 0.052635
# 	 partial train loss (single batch): 0.050984
# 	 partial train loss (single batch): 0.052847
# 	 partial train loss (single batch): 0.052593
# 	 partial train loss (single batch): 0.052944
# 	 partial train loss (single batch): 0.052157
# 	 partial train loss (single batch): 0.051656
# 	 partial train loss (single batch): 0.052776
# 	 partial train loss (single batch): 0.052538
# 	 partial train loss (single batch): 0.052563
# 	 partial train loss (single batch): 0.051842
# 	 partial train loss (single batch): 0.052742
# 	 partial train loss (single batch): 0.053232
# 	 partial train loss (single batch): 0.052530
# 	 partial train loss (single batch): 0.052595
# 	 partial train loss (single batch): 0.051845
# 	 partial train loss (single batch): 0.053595
# 	 partial train loss (single batch): 0.052215
# 	 partial train loss (single batch): 0.052484
# 	 partial train loss (single batch): 0.052588
# 	 partial train loss (single batch): 0.052524
# 	 partial train loss (single batch): 0.052243
# 	 partial train loss (single batch): 0.052330
# 	 partial train loss (single batch): 0.052371
# 	 partial train loss (single batch): 0.053143
# 	 partial train loss (single batch): 0.052879
# 	 partial train loss (single batch): 0.052583
# 	 partial train loss (single batch): 0.051792
# 	 partial train loss (single batch): 0.051896
# 	 partial train loss (single batch): 0.052102
# 	 partial train loss (single batch): 0.052385
# 	 partial train loss (single batch): 0.052277
# 	 partial train loss (single batch): 0.052980
# 	 partial train loss (single batch): 0.052011
# 	 partial train loss (single batch): 0.051831
# 	 partial train loss (single batch): 0.053397
# 	 partial train loss (single batch): 0.050965
# 	 partial train loss (single batch): 0.052606
# 	 partial train loss (single batch): 0.052374
# 	 partial train loss (single batch): 0.052439
# 	 partial train loss (single batch): 0.052964
# 	 partial train loss (single batch): 0.052197
# 	 partial train loss (single batch): 0.053500
# 	 partial train loss (single batch): 0.052073
# 	 partial train loss (single batch): 0.051760
# 	 partial train loss (single batch): 0.053475
# 	 partial train loss (single batch): 0.052811
# 	 partial train loss (single batch): 0.051884
# 	 partial train loss (single batch): 0.051925
# 	 partial train loss (single batch): 0.052720
# 	 partial train loss (single batch): 0.052455
# 	 partial train loss (single batch): 0.052828
# 	 partial train loss (single batch): 0.051894
# 	 partial train loss (single batch): 0.052778
# 	 partial train loss (single batch): 0.053540
# 	 partial train loss (single batch): 0.052702
# 	 partial train loss (single batch): 0.052347
# 	 partial train loss (single batch): 0.052322
# 	 partial train loss (single batch): 0.053777
# ...
# 	 partial train loss (single batch): 0.050400
# 	 partial train loss (single batch): 0.049592
# 	 partial train loss (single batch): 0.049626
# 	 partial train loss (single batch): 0.050441
# 	 partial train loss (single batch): 0.050499
# 	 partial train loss (single batch): 0.049721
# 	 partial train loss (single batch): 0.050314
# 	 partial train loss (single batch): 0.048321
# 	 partial train loss (single batch): 0.050406
# 	 partial train loss (single batch): 0.050120
# 	 partial train loss (single batch): 0.050478
# 	 partial train loss (single batch): 0.050606
# 	 partial train loss (single batch): 0.049569
# 	 partial train loss (single batch): 0.050428
# 	 partial train loss (single batch): 0.049899
# 	 partial train loss (single batch): 0.050617
# 	 partial train loss (single batch): 0.049750
# 	 partial train loss (single batch): 0.050322
# 	 partial train loss (single batch): 0.050588
# 	 partial train loss (single batch): 0.049762
# 	 partial train loss (single batch): 0.050374
# 	 partial train loss (single batch): 0.049031
# 	 partial train loss (single batch): 0.051060
# 	 partial train loss (single batch): 0.050309
# 	 partial train loss (single batch): 0.050481
# 	 partial train loss (single batch): 0.049873
# 	 partial train loss (single batch): 0.050040
# 	 partial train loss (single batch): 0.049557
# 	 partial train loss (single batch): 0.049818
# 	 partial train loss (single batch): 0.050138
# 	 partial train loss (single batch): 0.050577
# 	 partial train loss (single batch): 0.050536
# 	 partial train loss (single batch): 0.050571
# 	 partial train loss (single batch): 0.049450
# 	 partial train loss (single batch): 0.049543
# 	 partial train loss (single batch): 0.050332
# 	 partial train loss (single batch): 0.050166
# 	 partial train loss (single batch): 0.050169
# 	 partial train loss (single batch): 0.050522
# 	 partial train loss (single batch): 0.050155
# 	 partial train loss (single batch): 0.049451
# 	 partial train loss (single batch): 0.051307
# 	 partial train loss (single batch): 0.048336
# 	 partial train loss (single batch): 0.050187
# 	 partial train loss (single batch): 0.050151
# 	 partial train loss (single batch): 0.050144
# 	 partial train loss (single batch): 0.050520
# 	 partial train loss (single batch): 0.050177
# 	 partial train loss (single batch): 0.051152
# 	 partial train loss (single batch): 0.049719
# 	 partial train loss (single batch): 0.049792
# 	 partial train loss (single batch): 0.051030
# 	 partial train loss (single batch): 0.051102
# 	 partial train loss (single batch): 0.049682
# 	 partial train loss (single batch): 0.049644
# 	 partial train loss (single batch): 0.050080
# 	 partial train loss (single batch): 0.050014
# 	 partial train loss (single batch): 0.049865
# 	 partial train loss (single batch): 0.050154
# 	 partial train loss (single batch): 0.050318
# 	 partial train loss (single batch): 0.051313
# 	 partial train loss (single batch): 0.050617
# 	 partial train loss (single batch): 0.049978
# 	 partial train loss (single batch): 0.050545
# 	 partial train loss (single batch): 0.051353
# 	 partial train loss (single batch): 0.051119
# 	 partial train loss (single batch): 0.050921
# 	 partial train loss (single batch): 0.050908
# 	 partial train loss (single batch): 0.050484
# 	 partial train loss (single batch): 0.050040
# 	 partial train loss (single batch): 0.048901
# 	 partial train loss (single batch): 0.049470
# 	 partial train loss (single batch): 0.050460
# 	 partial train loss (single batch): 0.050500
# 	 partial train loss (single batch): 0.049584
# 	 partial train loss (single batch): 0.050265
# 	 partial train loss (single batch): 0.049395
# 	 partial train loss (single batch): 0.050332
# 	 partial train loss (single batch): 0.049970
# 	 partial train loss (single batch): 0.049258
# 	 partial train loss (single batch): 0.049957
# 	 partial train loss (single batch): 0.050554
# 	 partial train loss (single batch): 0.050623
# 	 partial train loss (single batch): 0.051072
# 	 partial train loss (single batch): 0.050313
# 	 partial train loss (single batch): 0.048403
# 	 partial train loss (single batch): 0.049025
# 	 partial train loss (single batch): 0.050773
# 	 partial train loss (single batch): 0.050699
# 	 partial train loss (single batch): 0.050278
# 	 partial train loss (single batch): 0.049614
# 	 partial train loss (single batch): 0.051156
# 	 partial train loss (single batch): 0.050424
# 	 partial train loss (single batch): 0.049021
# 	 partial train loss (single batch): 0.049338
# 	 partial train loss (single batch): 0.048525
# 	 partial train loss (single batch): 0.049750
# 	 partial train loss (single batch): 0.050224
# 	 partial train loss (single batch): 0.050755
# 	 partial train loss (single batch): 0.050684
# 	 partial train loss (single batch): 0.050874
# 	 partial train loss (single batch): 0.051113
# 	 partial train loss (single batch): 0.050035
# 	 partial train loss (single batch): 0.050568
# 	 partial train loss (single batch): 0.050789
# 	 partial train loss (single batch): 0.050507
# 	 partial train loss (single batch): 0.050829
# 	 partial train loss (single batch): 0.049825
# 	 partial train loss (single batch): 0.051165
# 	 partial train loss (single batch): 0.050884
# 	 partial train loss (single batch): 0.050006
# 	 partial train loss (single batch): 0.050022
# 	 partial train loss (single batch): 0.050033
# 	 partial train loss (single batch): 0.050058
# 	 partial train loss (single batch): 0.049829
# 	 partial train loss (single batch): 0.050211
# 	 partial train loss (single batch): 0.050071
# 	 partial train loss (single batch): 0.050780
# 	 partial train loss (single batch): 0.051524
# 	 partial train loss (single batch): 0.050474
# 	 partial train loss (single batch): 0.050730
# 	 partial train loss (single batch): 0.049317
# 	 partial train loss (single batch): 0.050648
# 	 partial train loss (single batch): 0.050778
# 	 partial train loss (single batch): 0.050539
# 	 partial train loss (single batch): 0.049610
# 	 partial train loss (single batch): 0.049786
# 	 partial train loss (single batch): 0.050893
# 	 partial train loss (single batch): 0.050054
# 	 partial train loss (single batch): 0.050977
# 	 partial train loss (single batch): 0.049103
# 	 partial train loss (single batch): 0.049789
# 	 partial train loss (single batch): 0.050107
# 	 partial train loss (single batch): 0.051631
# 	 partial train loss (single batch): 0.050403
# 	 partial train loss (single batch): 0.050634
# 	 partial train loss (single batch): 0.049845
# 	 partial train loss (single batch): 0.049746
# 	 partial train loss (single batch): 0.050978
# 	 partial train loss (single batch): 0.050531
# 	 partial train loss (single batch): 0.049474
# 	 partial train loss (single batch): 0.048613
# 	 partial train loss (single batch): 0.050455
# 	 partial train loss (single batch): 0.050308
# 	 partial train loss (single batch): 0.049641
# 	 partial train loss (single batch): 0.050304
# 	 partial train loss (single batch): 0.051320
# 	 partial train loss (single batch): 0.049814
# 	 partial train loss (single batch): 0.049889
# 	 partial train loss (single batch): 0.049848
# 	 partial train loss (single batch): 0.049314
# 	 partial train loss (single batch): 0.049704
# 	 partial train loss (single batch): 0.050432
# 	 partial train loss (single batch): 0.049790
# 	 partial train loss (single batch): 0.049912
# 	 partial train loss (single batch): 0.049077
# 	 partial train loss (single batch): 0.049923
#
#  EPOCH 19/20 	 train loss 0.050 	 val loss 0.039
# EPOCH 20/20
# 	 partial train loss (single batch): 0.051276
# 	 partial train loss (single batch): 0.050007
# 	 partial train loss (single batch): 0.051094
# 	 partial train loss (single batch): 0.050495
# 	 partial train loss (single batch): 0.049357
# 	 partial train loss (single batch): 0.050848
# 	 partial train loss (single batch): 0.050097
# 	 partial train loss (single batch): 0.049346
# 	 partial train loss (single batch): 0.050162
# 	 partial train loss (single batch): 0.049905
# 	 partial train loss (single batch): 0.049457
# 	 partial train loss (single batch): 0.049579
# 	 partial train loss (single batch): 0.048576
# 	 partial train loss (single batch): 0.050242
# 	 partial train loss (single batch): 0.050436
# 	 partial train loss (single batch): 0.050879
# 	 partial train loss (single batch): 0.049004
# 	 partial train loss (single batch): 0.050107
# 	 partial train loss (single batch): 0.049430
# 	 partial train loss (single batch): 0.050235
# 	 partial train loss (single batch): 0.049307
# 	 partial train loss (single batch): 0.049956
# 	 partial train loss (single batch): 0.050647
# 	 partial train loss (single batch): 0.050673
# 	 partial train loss (single batch): 0.050062
# 	 partial train loss (single batch): 0.050716
# 	 partial train loss (single batch): 0.049778
# 	 partial train loss (single batch): 0.048864
# 	 partial train loss (single batch): 0.049859
# 	 partial train loss (single batch): 0.050226
# 	 partial train loss (single batch): 0.050653
# 	 partial train loss (single batch): 0.050053
# 	 partial train loss (single batch): 0.049405
# 	 partial train loss (single batch): 0.049419
# 	 partial train loss (single batch): 0.050393
# 	 partial train loss (single batch): 0.050698
# 	 partial train loss (single batch): 0.049719
# 	 partial train loss (single batch): 0.050037
# 	 partial train loss (single batch): 0.048382
# 	 partial train loss (single batch): 0.050355
# 	 partial train loss (single batch): 0.050025
# 	 partial train loss (single batch): 0.050614
# 	 partial train loss (single batch): 0.050301
# 	 partial train loss (single batch): 0.049258
# 	 partial train loss (single batch): 0.049659
# 	 partial train loss (single batch): 0.049809
# 	 partial train loss (single batch): 0.050566
# 	 partial train loss (single batch): 0.049849
# 	 partial train loss (single batch): 0.049953
# 	 partial train loss (single batch): 0.050600
# 	 partial train loss (single batch): 0.050089
# 	 partial train loss (single batch): 0.049831
# 	 partial train loss (single batch): 0.048860
# 	 partial train loss (single batch): 0.050949
# 	 partial train loss (single batch): 0.050092
# 	 partial train loss (single batch): 0.050445
# 	 partial train loss (single batch): 0.050143
# 	 partial train loss (single batch): 0.050184
# 	 partial train loss (single batch): 0.049536
# 	 partial train loss (single batch): 0.050301
# 	 partial train loss (single batch): 0.050314
# 	 partial train loss (single batch): 0.050955
# 	 partial train loss (single batch): 0.050885
# 	 partial train loss (single batch): 0.050353
# 	 partial train loss (single batch): 0.049182
# 	 partial train loss (single batch): 0.049401
# 	 partial train loss (single batch): 0.049791
# 	 partial train loss (single batch): 0.049937
# 	 partial train loss (single batch): 0.050014
# 	 partial train loss (single batch): 0.050721
# 	 partial train loss (single batch): 0.049807
# 	 partial train loss (single batch): 0.049253
# 	 partial train loss (single batch): 0.051213
# 	 partial train loss (single batch): 0.048721
# 	 partial train loss (single batch): 0.050255
# 	 partial train loss (single batch): 0.049986
# 	 partial train loss (single batch): 0.050167
# 	 partial train loss (single batch): 0.050277
# 	 partial train loss (single batch): 0.050119
# 	 partial train loss (single batch): 0.051149
# 	 partial train loss (single batch): 0.049535
# 	 partial train loss (single batch): 0.049522
# 	 partial train loss (single batch): 0.050970
# 	 partial train loss (single batch): 0.050602
# 	 partial train loss (single batch): 0.049648
# 	 partial train loss (single batch): 0.049586
# 	 partial train loss (single batch): 0.050046
# 	 partial train loss (single batch): 0.050080
# 	 partial train loss (single batch): 0.049982
# 	 partial train loss (single batch): 0.049973
# 	 partial train loss (single batch): 0.049927
# 	 partial train loss (single batch): 0.051171
# 	 partial train loss (single batch): 0.050625
# 	 partial train loss (single batch): 0.049997
# 	 partial train loss (single batch): 0.050296
# 	 partial train loss (single batch): 0.051180
# 	 partial train loss (single batch): 0.051200
# 	 partial train loss (single batch): 0.050803
# 	 partial train loss (single batch): 0.050485
# 	 partial train loss (single batch): 0.050238
# 	 partial train loss (single batch): 0.050073
# 	 partial train loss (single batch): 0.048786
# 	 partial train loss (single batch): 0.049689
# 	 partial train loss (single batch): 0.050335
# 	 partial train loss (single batch): 0.050580
# 	 partial train loss (single batch): 0.049268
# 	 partial train loss (single batch): 0.050140
# 	 partial train loss (single batch): 0.049531
# 	 partial train loss (single batch): 0.050139
# 	 partial train loss (single batch): 0.049926
# 	 partial train loss (single batch): 0.049110
# 	 partial train loss (single batch): 0.049900
# 	 partial train loss (single batch): 0.050730
# 	 partial train loss (single batch): 0.050675
# 	 partial train loss (single batch): 0.051362
# 	 partial train loss (single batch): 0.050333
# 	 partial train loss (single batch): 0.048345
# 	 partial train loss (single batch): 0.049036
# 	 partial train loss (single batch): 0.050608
# 	 partial train loss (single batch): 0.050814
# 	 partial train loss (single batch): 0.049837
# 	 partial train loss (single batch): 0.049851
# 	 partial train loss (single batch): 0.051090
# 	 partial train loss (single batch): 0.050039
# 	 partial train loss (single batch): 0.048711
# 	 partial train loss (single batch): 0.049322
# 	 partial train loss (single batch): 0.048708
# 	 partial train loss (single batch): 0.049565
# 	 partial train loss (single batch): 0.050500
# 	 partial train loss (single batch): 0.050426
# 	 partial train loss (single batch): 0.050130
# 	 partial train loss (single batch): 0.050357
# 	 partial train loss (single batch): 0.050803
# 	 partial train loss (single batch): 0.050124
# 	 partial train loss (single batch): 0.050459
# 	 partial train loss (single batch): 0.050576
# 	 partial train loss (single batch): 0.050463
# 	 partial train loss (single batch): 0.050860
# 	 partial train loss (single batch): 0.049982
# 	 partial train loss (single batch): 0.051310
# 	 partial train loss (single batch): 0.050910
# 	 partial train loss (single batch): 0.050273
# 	 partial train loss (single batch): 0.049877
# 	 partial train loss (single batch): 0.050023
# 	 partial train loss (single batch): 0.050264
# 	 partial train loss (single batch): 0.049132
# 	 partial train loss (single batch): 0.049919
# 	 partial train loss (single batch): 0.050145
# 	 partial train loss (single batch): 0.050441
# 	 partial train loss (single batch): 0.051216
# 	 partial train loss (single batch): 0.050288
# 	 partial train loss (single batch): 0.050621
# 	 partial train loss (single batch): 0.049349
# 	 partial train loss (single batch): 0.050150
# 	 partial train loss (single batch): 0.050499
# 	 partial train loss (single batch): 0.050313
# 	 partial train loss (single batch): 0.049492
# 	 partial train loss (single batch): 0.049754
# 	 partial train loss (single batch): 0.050843
# 	 partial train loss (single batch): 0.050192
# 	 partial train loss (single batch): 0.051057
# 	 partial train loss (single batch): 0.049060
# 	 partial train loss (single batch): 0.049893
# 	 partial train loss (single batch): 0.050048
# 	 partial train loss (single batch): 0.051420
# 	 partial train loss (single batch): 0.050328
# 	 partial train loss (single batch): 0.050534
# 	 partial train loss (single batch): 0.049193
# 	 partial train loss (single batch): 0.049442
# 	 partial train loss (single batch): 0.050733
# 	 partial train loss (single batch): 0.050250
# 	 partial train loss (single batch): 0.049203
# 	 partial train loss (single batch): 0.048556
# 	 partial train loss (single batch): 0.049990
# 	 partial train loss (single batch): 0.049873
# 	 partial train loss (single batch): 0.049626
# 	 partial train loss (single batch): 0.050073
# 	 partial train loss (single batch): 0.051017
# 	 partial train loss (single batch): 0.050010
# 	 partial train loss (single batch): 0.049675
# 	 partial train loss (single batch): 0.049948
# 	 partial train loss (single batch): 0.049327
# 	 partial train loss (single batch): 0.049765
# 	 partial train loss (single batch): 0.050276
# 	 partial train loss (single batch): 0.049103
# 	 partial train loss (single batch): 0.050062
# 	 partial train loss (single batch): 0.048791
# 	 partial train loss (single batch): 0.049850
#
#  EPOCH 20/20 	 train loss 0.050 	 val loss 0.039
